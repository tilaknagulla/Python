# %%
corpus="""
Hello Welcome to Talent Arena.Where hidden talent shows to the world,Please do follow to support talent arena
"""
# Out:
# '\nHello Welcome to Talent Arena.Where hidden talent shows to the world,Please do follow to support talent arena\n'

# %%
import nltk
nltk.download('punkt_tab')
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
corpus = """
Hello Welcome to Talent Arena. Where hidden talent shows to the world! Please do follow to support talent arena.
""".strip()

from nltk.tokenize import sent_tokenize
documents=sent_tokenize(corpus)

for sentance in documents:
    print(sentance)
# Out:
# Hello Welcome to Talent Arena. Where hidden talent shows to the world! Please do follow to support talent arena.
# Hello Welcome to Talent Arena.
# Where hidden talent shows to the world!
# Please do follow to support talent arena.

# %%
from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  'to',
#  'Talent',
#  'Arena',
#  '.',
#  'Where',
#  'hidden',
#  'talent',
#  'shows',
#  'to',
#  'the',
#  'world',
#  '!',
#  'Please',
#  'do',
#  'follow',
#  'to',
#  'support',
#  'talent',
#  'arena',
#  '.']

# %%
## Sentance --> Words
for sentance in documents:
  print(word_tokenize(sentance))
# Out:
# ['Hello', 'Welcome', 'to', 'Talent', 'Arena', '.']
# ['Where', 'hidden', 'talent', 'shows', 'to', 'the', 'world', '!']
# ['Please', 'do', 'follow', 'to', 'support', 'talent', 'arena', '.']

# %%
"""Difference b/w word tokenizer and Treebankwordtokenizer? 
Treebankwordtokenizer function will not consider the fullstops in the middile of the paragrash as a seperate word it will 
it will consider only the last fullstop as seperate word"""

## Tree bank word tokenizer
from nltk.tokenize import TreebankWordTokenizer, TreebankWordDetokenizer

corpus = """Hello Welcome to Talent Arena. Where hidden talent shows to the world! Please do follow to support talent arena."""

tokenizer = TreebankWordTokenizer()
#detokenizer = TreebankWordDetokenizer()

tokens = tokenizer.tokenize(corpus)
print(tokens)
"""
text = detokenizer.detokenize(tokens)
print(text)
"""
# Out:
# ['Hello', 'Welcome', 'to', 'Talent', 'Arena.', 'Where', 'hidden', 'talent', 'shows', 'to', 'the', 'world', '!', 'Please', 'do', 'follow', 'to', 'support', 'talent', 'arena', '.']
# '\ntext = detokenizer.detokenize(tokens)\nprint(text)\n'
