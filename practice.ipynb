# %%
## Remove duplicates from the word
# Methid -1
word="Programming"
result=""
for ch in word:
    if ch not in result:
        result=result+ch

print(result)
# Out:
# Progamin

# %%
#Method 
word ="Elamarru"
result="".join(dict.fromkeys(word))
print(result)
# Out:
# Elamru

# %%
## Printing pattrens
for i in range(1, 5):
    for j in range(1, 5):
        if i >= j:
            print("*", end="")
        else:
            print(" ", end="")
    print()   # new line AFTER inner loop
# Out:
# *
# **
# ***
# ****
