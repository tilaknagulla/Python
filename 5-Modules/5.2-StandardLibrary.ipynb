# %% [markdown]
# Standard Library Overview:

# %% [markdown]
# Python's standard library is a vast collection of modules and packages that come bundled with python,providing a wide range of functionalities out of the box.Here's an overview of some of the most commonly used modules and packages in the python standard library.

# %%
import array
arr=array.array(i,[1,2,3,4])
print(arr)

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## random
import random
print(random.randint(1,10))
print(random.choice(['Tilak','Sai','Kumar']))
# Out:
# 9
# Kumar

# %%
#File and Directory access
import os
print(os.getcwd())
# Out:
# c:\Python\5-Modules

# %%
os.mkdir('test_dir')

# %%
##High level operations
import shutil
shutil.copyfile('source.txt','copy_file.txt')
# Out:
# 'copy_file.txt'

# %%
### Data Serialization
import json
data={'name':'Tilak','age':27}
json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Tilak", "age": 27}
# <class 'str'>
# {'name': 'Tilak', 'age': 27}
# <class 'dict'>

# %%
# csv
import csv

with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Tilak',25])
    writer.writerow(['Sai',27])

with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Tilak', '25']
# ['Sai', '27']

# %%
#datetime

from datetime import datetime,timedelta
now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-03-14 13:27:47.793648
# 2026-03-13 13:27:47.793648

# %%
import time
print(time.time())
time.sleep(3)
print(time.time())
# Out:
# 1773480528.730183
# 1773480531.7352335

# %%
## regular expression
import re
pattern=r'\d+'
text="There are 148 apples in 456"
match=re.search(pattern,text)
print(match.group())
# Out:
# 148
